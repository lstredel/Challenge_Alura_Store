# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# %%
tienda1.insert(loc=0, column='Tienda Origen', value="Tienda 1")
tienda2.insert(loc=0, column='Tienda Origen', value="Tienda 2")
tienda3.insert(loc=0, column='Tienda Origen', value="Tienda 3")
tienda4.insert(loc=0, column='Tienda Origen', value="Tienda 4")

# %%
tienda1.head()
# Out:
#   Tienda Origen           Producto Categoría del Producto    Precio  \
# 0      Tienda 1  Asistente virtual           Electrónicos  164300.0
# 1      Tienda 1    Mesa de comedor                Muebles  192300.0
# 2      Tienda 1      Juego de mesa               Juguetes  209600.0
# 3      Tienda 1         Microondas      Electrodomésticos  757500.0
# 4      Tienda 1   Silla de oficina                Muebles  335200.0
#
#    Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 0          6900.0      16/01/2021      Pedro Gomez          Bogotá
# 1          8400.0      18/05/2022  Beatriz Morales        Medellín
# 2         15900.0      15/03/2021   Juan Fernandez       Cartagena
# 3         41000.0      03/05/2022   Juan Fernandez            Cali
# 4         20200.0      07/11/2020    Maria Alfonso        Medellín
#
#    Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 0             4  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#   Tienda Origen          Producto  Categoría del Producto    Precio  \
# 0      Tienda 2  Silla de oficina                 Muebles  283600.0
# 1      Tienda 2         Pandereta  Instrumentos musicales   76800.0
# 2      Tienda 2         Cama king                 Muebles  443300.0
# 3      Tienda 2         Cama king                 Muebles  906200.0
# 4      Tienda 2  Silla de oficina                 Muebles  397800.0
#
#    Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 0         15300.0      04/08/2021  Izabela de León        Medellín
# 1          2300.0      26/11/2020   Blanca Ramirez        Medellín
# 2         23800.0      22/10/2021  Izabela de León         Pereira
# 3         46400.0      04/05/2022    Maria Alfonso            Cali
# 4         19400.0      26/02/2022    Lucas Olivera          Bogotá
#
#    Calificación      Método de pago  Cantidad de cuotas      lat       lon
# 0             1               Nequi                   1  6.25184 -75.56359
# ...

# %%
Tiendas_Concatenadas = pd.concat([tienda1, tienda2, tienda3, tienda4], ignore_index=True)

# %%
Tiendas_Concatenadas.head()
# Out:
#   Tienda Origen           Producto Categoría del Producto    Precio  \
# 0      Tienda 1  Asistente virtual           Electrónicos  164300.0
# 1      Tienda 1    Mesa de comedor                Muebles  192300.0
# 2      Tienda 1      Juego de mesa               Juguetes  209600.0
# 3      Tienda 1         Microondas      Electrodomésticos  757500.0
# 4      Tienda 1   Silla de oficina                Muebles  335200.0
#
#    Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 0          6900.0      16/01/2021      Pedro Gomez          Bogotá
# 1          8400.0      18/05/2022  Beatriz Morales        Medellín
# 2         15900.0      15/03/2021   Juan Fernandez       Cartagena
# 3         41000.0      03/05/2022   Juan Fernandez            Cali
# 4         20200.0      07/11/2020    Maria Alfonso        Medellín
#
#    Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 0             4  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
Tiendas_Concatenadas.tail()
# Out:
#      Tienda Origen            Producto   Categoría del Producto    Precio  \
# 9430      Tienda 4     Mesa de comedor                  Muebles  227700.0
# 9431      Tienda 4    Silla de oficina                  Muebles  342000.0
# 9432      Tienda 4        Vaso térmico     Deportes y diversión   36700.0
# 9433      Tienda 4        Set de ollas  Artículos para el hogar  151800.0
# 9434      Tienda 4  Cuerda para saltar     Deportes y diversión   11200.0
#
#       Costo de envío Fecha de Compra        Vendedor Lugar de Compra  \
# 9430         12600.0      12/02/2020   Camila Rivera        Medellín
# 9431         18600.0      17/05/2022   Felipe Santos     Bucaramanga
# 9432          2400.0      03/05/2022   Camila Rivera          Bogotá
# 9433          8300.0      15/06/2020  Blanca Ramirez            Cali
# 9434          1300.0      17/11/2021   Felipe Santos          Bogotá
#
#       Calificación      Método de pago  Cantidad de cuotas      lat       lon
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Tiendas_Concatenadas.to_csv("/content/drive/MyDrive/Tiendas_Concatenadas.csv", index=False, sep=";")

# %%
Tiendas_Concatenadas.head()
# Out:
#   Tienda Origen           Producto Categoría del Producto    Precio  \
# 0      Tienda 1  Asistente virtual           Electrónicos  164300.0
# 1      Tienda 1    Mesa de comedor                Muebles  192300.0
# 2      Tienda 1      Juego de mesa               Juguetes  209600.0
# 3      Tienda 1         Microondas      Electrodomésticos  757500.0
# 4      Tienda 1   Silla de oficina                Muebles  335200.0
#
#    Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 0          6900.0      16/01/2021      Pedro Gomez          Bogotá
# 1          8400.0      18/05/2022  Beatriz Morales        Medellín
# 2         15900.0      15/03/2021   Juan Fernandez       Cartagena
# 3         41000.0      03/05/2022   Juan Fernandez            Cali
# 4         20200.0      07/11/2020    Maria Alfonso        Medellín
#
#    Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 0             4  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
Tiendas_Concatenadas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9435 entries, 0 to 9434
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Tienda Origen           9435 non-null   object
#  1   Producto                9435 non-null   object
#  2   Categoría del Producto  9435 non-null   object
#  3   Precio                  9435 non-null   float64
#  4   Costo de envío          9435 non-null   float64
#  5   Fecha de Compra         9435 non-null   object
#  6   Vendedor                9435 non-null   object
#  7   Lugar de Compra         9435 non-null   object
#  8   Calificación            9435 non-null   int64
#  9   Método de pago          9435 non-null   object
#  10  Cantidad de cuotas      9435 non-null   int64
#  11  lat                     9435 non-null   float64
#  12  lon                     9435 non-null   float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 958.4+ KB

# %%
Tiendas_Concatenadas.isnull().sum()
# Out:
# Tienda Origen             0
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %% [markdown]
# #1. Análisis de facturación

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
ventas_totales_por_tienda = Tiendas_Concatenadas.groupby("Tienda Origen")["Precio"].sum()
ventas_totales_por_tienda.head()
# Out:
# Tienda Origen
# Tienda 1   1,150,880,400
# Tienda 2   1,116,343,500
# Tienda 3   1,098,019,600
# Tienda 4   1,038,375,700
# Name: Precio, dtype: float64

# %% [markdown]
# # 2. Ventas por categoría

# %%
ventas_totales_por_categoria = Tiendas_Concatenadas.groupby(["Categoría del Producto"])["Precio"].agg(["sum", "count"])
display(ventas_totales_por_categoria.head(10))
# Out:
#                                   sum  count
# Categoría del Producto
# Artículos para el hogar    57,579,800    730
# Deportes y diversión      142,977,700   1113
# Electrodomésticos       1,324,751,100   1149
# Electrónicos            1,660,576,500   1772
# Instrumentos musicales    348,772,600    753
# Juguetes                   73,604,400   1290
# Libros                     37,696,100    742
# Muebles                   757,661,000   1886

# %%
ventas_totales_por_tienda_y_categoria = Tiendas_Concatenadas.groupby(["Tienda Origen", "Categoría del Producto"])["Precio"].agg(["sum", "count"])
display(ventas_totales_por_tienda_y_categoria.head(50))
# Out:
#                                               sum  count
# Tienda Origen Categoría del Producto
# Tienda 1      Artículos para el hogar  12,698,400    171
#               Deportes y diversión     39,290,000    284
#               Electrodomésticos       363,685,200    312
#               Electrónicos            429,493,500    448
#               Instrumentos musicales   91,299,000    182
#               Juguetes                 17,995,700    324
#               Libros                    8,784,900    173
#               Muebles                 187,633,700    465
# Tienda 2      Artículos para el hogar  14,746,900    181
#               Deportes y diversión     34,744,500    275
#               Electrodomésticos       348,567,800    305
#               Electrónicos            410,831,100    422
#               Instrumentos musicales  104,990,300    224
#               Juguetes                 15,945,400    313
#               Libros                   10,091,200    197
# ...

# %%
ventas_totales_por_tienda_y_categoria = Tiendas_Concatenadas.groupby(["Categoría del Producto","Tienda Origen"])["Precio"].agg(["sum", "count"])
display(ventas_totales_por_tienda_y_categoria.head(50))
# Out:
#                                               sum  count
# Categoría del Producto  Tienda Origen
# Artículos para el hogar Tienda 1       12,698,400    171
#                         Tienda 2       14,746,900    181
#                         Tienda 3       15,060,000    177
#                         Tienda 4       15,074,500    201
# Deportes y diversión    Tienda 1       39,290,000    284
#                         Tienda 2       34,744,500    275
#                         Tienda 3       35,593,100    277
#                         Tienda 4       33,350,100    277
# Electrodomésticos       Tienda 1      363,685,200    312
#                         Tienda 2      348,567,800    305
#                         Tienda 3      329,237,900    278
#                         Tienda 4      283,260,200    254
# Electrónicos            Tienda 1      429,493,500    448
#                         Tienda 2      410,831,100    422
#                         Tienda 3      410,775,800    451
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
Calificacion_Tiendas = Tiendas_Concatenadas.groupby(["Tienda Origen", "Calificación"])["Calificación"].count().rename("Cantidad")
Calificacion_Tiendas.head(30)
# Out:
# Tienda Origen  Calificación
# Tienda 1       1                319
#                2                 86
#                3                218
#                4                444
#                5               1292
# Tienda 2       1                273
#                2                 93
#                3                209
#                4                482
#                5               1302
# Tienda 3       1                297
#                2                 79
#                3                193
#                4                434
#                5               1356
# Tienda 4       1                310
#                2                 85
#                3                210
#                4                453
#                5               1300
# Name: Cantidad, dtype: int64

# %%
total_por_tienda = Tiendas_Concatenadas.groupby("Tienda Origen")["Calificación"].count().rename("Total Calificado")
total_por_tienda.head()
# Out:
# Tienda Origen
# Tienda 1    2359
# Tienda 2    2359
# Tienda 3    2359
# Tienda 4    2358
# Name: Total Calificado, dtype: int64

# %%
df_frecuencias = Calificacion_Tiendas.reset_index()

# %%
df_totales = total_por_tienda.reset_index()

# %%
df_combinado = df_frecuencias.merge(
    df_totales[['Tienda Origen', 'Total Calificado']],
    on='Tienda Origen',
    how='left'
)
df_combinado.head(30)
# Out:
#    Tienda Origen  Calificación  Cantidad  Total Calificado
# 0       Tienda 1             1       319              2359
# 1       Tienda 1             2        86              2359
# 2       Tienda 1             3       218              2359
# 3       Tienda 1             4       444              2359
# 4       Tienda 1             5      1292              2359
# 5       Tienda 2             1       273              2359
# 6       Tienda 2             2        93              2359
# 7       Tienda 2             3       209              2359
# 8       Tienda 2             4       482              2359
# 9       Tienda 2             5      1302              2359
# 10      Tienda 3             1       297              2359
# 11      Tienda 3             2        79              2359
# 12      Tienda 3             3       193              2359
# 13      Tienda 3             4       434              2359
# 14      Tienda 3             5      1356              2359
# ...

# %%
df_combinado['Porcentaje por Calificación'] = (
    df_combinado['Cantidad'] / df_combinado['Total Calificado']
) * 100
pd.options.display.float_format = '{:,.0f}'.format
df_combinado.head(30)
# Out:
#    Tienda Origen  Calificación  Cantidad  Total Calificado  \
# 0       Tienda 1             1       319              2359
# 1       Tienda 1             2        86              2359
# 2       Tienda 1             3       218              2359
# 3       Tienda 1             4       444              2359
# 4       Tienda 1             5      1292              2359
# 5       Tienda 2             1       273              2359
# 6       Tienda 2             2        93              2359
# 7       Tienda 2             3       209              2359
# 8       Tienda 2             4       482              2359
# 9       Tienda 2             5      1302              2359
# 10      Tienda 3             1       297              2359
# 11      Tienda 3             2        79              2359
# 12      Tienda 3             3       193              2359
# 13      Tienda 3             4       434              2359
# 14      Tienda 3             5      1356              2359
# ...

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Group by 'Producto' and count the number of sales for each product.
# .size() returns a Series with the counts, and .reset_index(name='Cantidad de Ventas')
# converts it into a DataFrame with a column named 'Cantidad de Ventas'.
productos_vendidos_counts = Tiendas_Concatenadas.groupby("Producto").size().reset_index(name='Cantidad de Ventas')

# Sort this new DataFrame by 'Cantidad de Ventas' in descending order
ventas_top_por_tienda = productos_vendidos_counts.sort_values(by='Cantidad de Ventas', ascending=False)

# Display the top 10 most sold products
display(ordenado_descendente.head(10))
# Out:
#                      Producto  Cantidad de Ventas
# 32              Mesa de noche                 210
# 33                 Microondas                 206
# 12  Carrito de control remoto                 206
# 7                     Batería                 203
# 11                  Cama king                 201
# 35        Modelado predictivo                 200
# 40           Secadora de ropa                 200
# 41               Set de ollas                 200
# 10                   Cama box                 199
# 9     Bloques de construcción                 199

# %%
df_ventas_por_producto = Tiendas_Concatenadas.groupby('Producto').size().reset_index(name='Total_Cantidad_Vendida_Global')

# %%
N = 10
df_productos_top_10 = df_ventas_por_producto.sort_values(
    by='Total_Cantidad_Vendida_Global',  # Columna de conteo
    ascending=False                     # De mayor a menor
).head(N)
print(f"--- Top {N} Productos Más Vendidos (por Conteo) ---")
display(df_productos_top_10)
# Out:
# --- Top 10 Productos Más Vendidos (por Conteo) ---
#                      Producto  Total_Cantidad_Vendida_Global
# 32              Mesa de noche                            210
# 33                 Microondas                            206
# 12  Carrito de control remoto                            206
# 7                     Batería                            203
# 11                  Cama king                            201
# 35        Modelado predictivo                            200
# 40           Secadora de ropa                            200
# 41               Set de ollas                            200
# 10                   Cama box                            199
# 9     Bloques de construcción                            199

# %%
productos_top_global = df_productos_top_10['Producto'].unique()
df_solo_top_productos = Tiendas_Concatenadas[
    Tiendas_Concatenadas['Producto'].isin(productos_top_global)
]
df_participacion_tienda = df_solo_top_productos.groupby(['Producto', 'Tienda Origen']).size().reset_index(name='Cantidad_Vendida_Tienda')
df_participacion_final = df_participacion_tienda.merge(
    df_ventas_por_producto,
    on='Producto',
    how='left'
)
df_participacion_final['Porcentaje_Participacion'] = (
    df_participacion_final['Cantidad_Vendida_Tienda'] / df_participacion_final['Total_Cantidad_Vendida_Global']
) * 100
pd.options.display.float_format = '{:,.0f}'.format

resumen_styled = df_participacion_final.style.format({
    'Cantidad_Vendida_Tienda': '{:,.0f}',
    'Total_Cantidad_Vendida_Global': '{:,.0f}',
    'Porcentaje_Participacion': '{:,.2f}%' # Porcentaje con 2 decimales
})

print("--- Porcentaje de Participación por Tienda (Solo Productos Top 10) ---")
display(resumen_styled)
# Out:
# --- Porcentaje de Participación por Tienda (Solo Productos Top 10) ---
# <style type="text/css">
# </style>
# <table id="T_f2419" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2419_level0_col0" class="col_heading level0 col0" >Producto</th>
#       <th id="T_f2419_level0_col1" class="col_heading level0 col1" >Tienda Origen</th>
#       <th id="T_f2419_level0_col2" class="col_heading level0 col2" >Cantidad_Vendida_Tienda</th>
#       <th id="T_f2419_level0_col3" class="col_heading level0 col3" >Total_Cantidad_Vendida_Global</th>
#       <th id="T_f2419_level0_col4" class="col_heading level0 col4" >Porcentaje_Participacion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2419_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2419_row0_col0" class="data row0 col0" >Batería</td>
#       <td id="T_f2419_row0_col1" class="data row0 col1" >Tienda 1</td>
# ...

# %%
display(ordenado_descendente.tail(10))
# Out:
#                        Producto  Cantidad de Ventas
# 46                   Smartwatch                 172
# 37              Olla de presión                 172
# 42                 Set de vasos                 169
# 44                       Sillón                 168
# 2             Asistente virtual                 167
# 14  Ciencia de datos con Python                 166
# 22           Guitarra eléctrica                 165
# 34                      Mochila                 163
# 4     Auriculares con micrófono                 158
# 13                 Celular ABXY                 157

# %%
productos_top_global = Topten['Producto'].unique()

# %%
df_filtrado_por_producto = Tiendas_Concatenadas[
    Tiendas_Concatenadas['Producto'].isin(productos_top_global)
]

# %%
ventas_top_por_tienda = df_filtrado_por_producto.groupby(['Producto','Tienda Origen']).size().reset_index(name='Cantidad de Vent')

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
print("--- Cantidad Vendida de Productos Top Globales por Tienda ---")
display(ventas_top_por_tienda.head(10))
# Out:
# --- Cantidad Vendida de Productos Top Globales por Tienda ---
#                   Producto Tienda Origen  Cantidad de Vent
# 0                  Batería      Tienda 1                53
# 1                  Batería      Tienda 2                61
# 2                  Batería      Tienda 3                41
# 3                  Batería      Tienda 4                48
# 4  Bloques de construcción      Tienda 1                56
# 5  Bloques de construcción      Tienda 2                54
# 6  Bloques de construcción      Tienda 3                35
# 7  Bloques de construcción      Tienda 4                54
# 8                 Cama box      Tienda 1                44
# 9                 Cama box      Tienda 2                47

# %% [markdown]
# # 5. Envío promedio por tienda
